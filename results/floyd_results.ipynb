# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("floyd.csv")
df_columns = df.keys()
df.head()
# Out:
#    nodes   serial_time   parallel_2_threads   parallel_4_threads  \
# 0    100  8.101375e+03                 5524                 4850
# 1    250  9.609800e+04                72128                60067
# 2    500  6.608570e+05               453702               453079
# 3   1000  6.056945e+06              3740558              3985568
# 4   1500  1.836537e+07             14399517             17742819
#
#     parallel_6_threads   parallel_8_threads   parallel_10_threads  \
# 0                 5197                 4933                  4530
# 1                61031                76220                 59130
# 2               473045               480605                449018
# 3              5961869              8834878               3674094
# 4             12200614             12075275              11607691
#
#     parallel_12_threads   parallel_14_threads   parallel_16_threads
# 0                  4789                  5225                  4904
# ...

# %%
# Overview of Floyd
df.plot(x=df_columns[0], y=df_columns[1:], kind="line", marker="o")
plt.xticks(rotation=25)
plt.xlabel('Number of nodes')
plt.ylabel('Time Taken')
plt.title('Floyd\'s Algortihm - Time taken for different number of threads', fontsize=20)
plt.grid()
plt.legend()
plt.show()

# %%
# Serial vs Parallel Floyd - 2 Threads
df.plot(x=df_columns[0], y=[df_columns[1], df_columns[2]], kind="line", marker="o")
plt.xticks(rotation=25)
plt.xlabel('Number of nodes (N)')
plt.ylabel('Time Taken (us)')
plt.title('Floyd\'s Algortihm - Serial vs Parallel Execution Time', fontsize=20)
plt.grid()
plt.legend()
plt.show()

# %%
# Serial vs Parallel Floyd - 4 Threads
df.plot(x=df_columns[0], y=[df_columns[1], df_columns[3]], kind="line", marker="o")
plt.xticks(rotation=25)
plt.xlabel('Number of nodes (N)')
plt.ylabel('Time Taken (us)')
plt.title('Floyd\'s Algortihm - Serial vs Parallel Execution Time ', fontsize=20)
plt.grid()
plt.legend()
plt.show()

# %%
# Serial vs Parallel Floyd - 6 Threads
df.plot(x=df_columns[0], y=[df_columns[1], df_columns[4]], kind="line", marker="o")
plt.xticks(rotation=25)
plt.xlabel('Number of nodes (N)')
plt.ylabel('Time Taken (us)')
plt.title('Floyd\'s Algortihm - Serial vs Parallel Execution Time ', fontsize=20)
plt.grid()
plt.legend()
plt.show()

# %%
# Serial vs Parallel Floyd - 8 Threads
df.plot(x=df_columns[0], y=[df_columns[1], df_columns[5]], kind="line", marker="o")
plt.xticks(rotation=25)
plt.xlabel('Number of nodes (N)')
plt.ylabel('Time Taken (us)')
plt.title('Floyd\'s Algortihm - Serial vs Parallel Execution Time ', fontsize=20)
plt.grid()
plt.legend()
plt.show()

# %%
# Serial vs Parallel Floyd - 10 Threads
df.plot(x=df_columns[0], y=[df_columns[1], df_columns[6]], kind="line", marker="o")
plt.xticks(rotation=25)
plt.xlabel('Number of nodes (N)')
plt.ylabel('Time Taken (us)')
plt.title('Floyd\'s Algortihm - Serial vs Parallel Execution Time ', fontsize=20)
plt.grid()
plt.legend()
plt.show()

# %%
# Serial vs Parallel Floyd - 12 Threads
df.plot(x=df_columns[0], y=[df_columns[1], df_columns[7]], kind="line", marker="o")
plt.xticks(rotation=25)
plt.xlabel('Number of nodes (N)')
plt.ylabel('Time Taken (us)')
plt.title('Floyd\'s Algortihm - Serial vs Parallel Execution Time ', fontsize=20)
plt.grid()
plt.legend()
plt.show()

# %%
# Serial vs Parallel Floyd - 14 Threads
df.plot(x=df_columns[0], y=[df_columns[1], df_columns[8]], kind="line", marker="o")
plt.xticks(rotation=25)
plt.xlabel('Number of nodes (N)')
plt.ylabel('Time Taken (us)')
plt.title('Floyd\'s Algortihm - Serial vs Parallel Execution Time ', fontsize=20)
plt.grid()
plt.legend()
plt.show()

# %%
# Serial vs Parallel Floyd - 16 Threads
df.plot(x=df_columns[0], y=[df_columns[1], df_columns[9]], kind="line", marker="o")
plt.xticks(rotation=25)
plt.xlabel('Number of nodes (N)')
plt.ylabel('Time Taken (us)')
plt.title('Floyd\'s Algortihm - Serial vs Parallel Execution Time ', fontsize=20)
plt.grid()
plt.legend()
plt.show()
